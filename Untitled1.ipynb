# %%
import matplotlib.pyplot as plt # Plotting library
from matplotlib import cm # Color map for contour plots
from mpl_toolkits.mplot3d import Axes3D # #3D component Library
import numpy as np # Useful array manipulation library
from numpy.linalg import norm # Useful function to determine the euclidean distance between two vectors

# Here's the thing to use the interactive mode comment out
#%matplotlib widget
#%matplotlib notebook
# Sometimes is required to run this two times, also consider that the interactive mode is computationally expensive
# %matplotlib inline

# %%
N = 1000
def initialize(s):
    for key in s:
        wave_length = s[key]["wave_length"]
        s[key]["x"] = np.linspace(0, wave_length, N)        

SPECTRUM = {
    "red": {
        "wave_length": 700e-9,
        "frecuency": 480e-12,
        "k": 2*np.pi/700e-9,
        "w": 2*np.pi/480e-12,
    },
    "blue": {
        "wave_length": 450e-9,
        "frecuency": 620e-12,
        "k": 2*np.pi/450-9,
        "w": 2*np.pi/620-12
    },
    "radio": {
        "wave_length": 10000e6,
        "frecuency": 30,
        "k": 2*np.pi/10000e6,
        "w": 2*np.pi/30
    }
}

initialize(SPECTRUM)

E_fx0 = lambda t: np.exp(-t/0.368)

t = np.linspace(0, 10, N)

E_0 = 1

word="red"

y_red = E_0 * np.sin(SPECTRUM[word]["w"]*t - SPECTRUM[word]["k"]*SPECTRUM[word]["x"])
plt.plot(SPECTRUM['red']['x'], y_red, 'r')
plt.show()

word="blue"
y_blue = E_0 * np.sin(SPECTRUM[word]["w"]*t - SPECTRUM[word]["k"]*SPECTRUM[word]["x"])
plt.plot(SPECTRUM[word]['x'], y_blue, 'b')
plt.show()

word="radio"
y_radio = E_0 * np.sin(SPECTRUM[word]["w"]*t - SPECTRUM[word]["k"]*SPECTRUM[word]["x"])
plt.plot(SPECTRUM[word]['x'], y_radio, 'k')
plt.show()
#plt.show()
#plt.plot(x,y_blue, 'b')
#plt.show()
#plt.plot(x,y_radio, 'k')
#plt.show()]

# %%
N=100
#E
x = np.linspace(-2*np.pi, 2*np.pi , N)
y = np.sin(x)
z = np.linspace(0,0,N)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

plt.plot(x,y,z)

#B
x_b = np.linspace(-2*np.pi, 2*np.pi , N)
y_b = np.linspace(0,0,N)
z_b = np.sin(x)

plt.plot(x_b, y_b, z_b)

# Light direction (E X B)
x_l = np.linspace(-2*np.pi, 2*np.pi , N)
y_l = np.linspace(0,0,N)
z_l = np.linspace(0,0,N)

plt.plot(x_l, y_l ,z_l)
# EM Wave
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()

# %%
x = [0, 0, 0]
y = [0, 0, 0]
z = [0, 0, 0]

u = [1, 0, 0]
v = [0, 1, 0]
w = [0, 0, 1]

fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111, projection='3d')
ax.quiver(x,y,z,u,v,w)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

ax.set_xlim(-5, 5)
ax.set_ylim(-5, 5)
ax.set_zlim(-5, 5)

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#charge = [0,0,0]
#test_charge = [1,2,3]

#fig = plt.figure()
#ax = fig.add_subplot(111, projection='3d')
#ax.scatter([0,1], [0,0], [0,0])

class Charge:
    def __init__(self, position, charge):
        self.position = position
        self.charge = charge

class Experiment:
    def __init__(self):
        self.K=9e9
        self.charges=[]
        
    def add_charge(self,c):
        self.charges.append(c)
        
    def EField_at_charge(self, test_charge):
        # apply Coulomb Law
        e_field = 0
        v_hat=0
        for c in self.charges:
            s = test_charge.position - c.position
            dist = norm(s)
            v_hat = s/dist
            e_field += (experiment.K * c.charge * test_charge.charge * v_hat)/dist**2
        return e_field, v_hat
    
    def EField_at_point(self, point):
        # apply Coulomb Law
        e_field = 0
        v_hat=0
        e_field_magnitude = 0
        for c in self.charges:
            s = point - c.position
            dist = norm(s)
            v_hat = s/dist
            e_field += (experiment.K * c.charge * v_hat)/dist**2
        e_field_magnitude = norm(e_field)
        return e_field, v_hat, e_field_magnitude
    
    def EField_at_mesh(self, mesh):
        e_field = [[], [], []]
        e_field_magnitude = []
        v_hat = [[], [], []]
        
        ef_at = 0
        v_hat_at = 0
        ef_mag_at = 0
        
        for i in range(mesh.shape[1]):
            ef_at, v_hat_at, ef_mag_at = self.EField_at_point([mesh[0][i], mesh[1][i], mesh[2][i]])
            
            e_field[0].append(ef_at[0])
            e_field[1].append(ef_at[1])
            e_field[2].append(ef_at[2])
            
            v_hat[0].append(v_hat_at[0])
            v_hat[1].append(v_hat_at[1])
            v_hat[2].append(v_hat_at[2])
            
            e_field_magnitude.append(ef_mag_at)
            
        return np.array(e_field), np.array(v_hat_at), np.array(e_field_magnitude)
    
    def plot(self, fig):
        ax = fig.add_subplot(111, projection='3d')
        
        for c in self.charges:
            color = 'b'
            if c.charge >= 0:
                color = 'r'
            ax.scatter(c.position[0],c.position[1],c.position[2], color=color)
            
        return ax

# %%
experiment = Experiment()
c1 = Charge(np.array([0,0,0]), 2e-9)
test_charge = Charge(np.array([4,0,0]), 1)
experiment.add_charge(c1)

# %%
fig = plt.figure()
experiment.plot(fig)

# %%
e_field, v_hat = experiment.EField_at_charge(test_charge)

fig = plt.figure()
ax = experiment.plot(fig)

ax.scatter(test_charge.position[0], test_charge.position[1], test_charge.position[2])
ax.quiver(test_charge.position[0],test_charge.position[1],test_charge.position[2], v_hat[0],v_hat[1],v_hat[2], length=0.2, normalize=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#%matplotlib widget
#%matplotlib notebook
#%matplotlib inline

# Now with several charges
experiment = Experiment()
experiment.add_charge(Charge(np.array([0,0,0]), -6))
experiment.add_charge(Charge(np.array([0,0,0]), -2))
experiment.add_charge(Charge(np.array([0,0,0]), -2))
experiment.add_charge(Charge(np.array([0.5,0.,0.5]), 3))

test_charge = Charge(np.array([1,1,1]), 1)

e_field, v_hat = experiment.EField_at_charge(test_charge)

fig = plt.figure(figsize=(10,8))
ax = experiment.plot(fig)

ax.scatter(test_charge.position[0], test_charge.position[1], test_charge.position[2], color='y')
ax.quiver(test_charge.position[0], test_charge.position[1], test_charge.position[2], e_field[0], e_field[1], e_field[2], length=0.5, normalize=True)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

ax.set_xlim(-1,3)
ax.set_ylim(-1,3)
ax.set_zlim(-1,3)

plt.show()

# %%
#%matplotlib widget
#%matplotlib notebook
#%matplotlib inline

# Efield around a particle
r = np.linspace(-5, 5, N)
phi = np.linspace(0, 2*np.pi, N)
theta = np.linspace(0, 2*np.pi,N)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

plt.scatter(x,y,z)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#%matplotlib widget
#%matplotlib notebook
# %matplotlib inline

fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111, projection='3d')

x = np.linspace(-5,5, 10)
y = np.linspace(-5,5, 10)
z = np.linspace(-5,5, 10)

mgrid = []

for z_ in z:
    xx, yy = np.meshgrid(x,y)
    mgrid.append([xx, yy, z_])
    ax.scatter(xx,yy, z_,s=0.4)

plt.show()

# %%
#Compute it as a field
# %matplotlib widget
# %matplotlib notebook
#%matplotlib inline

experiment = Experiment()
experiment.add_charge(Charge(np.array([-1,   4.5,  0]), -6))
experiment.add_charge(Charge(np.array([ 0,   3.8, -0.1]), -2))
experiment.add_charge(Charge(np.array([ 0.5, 3.14 ,   -0.3]), -2))
experiment.add_charge(Charge(np.array([ 1,   2,    0.5]), 3))

x = np.linspace(-5,5, 10)
y = np.linspace(-5,5, 10)
z = np.linspace(-5,5, 10)

mesh = []

xx = []
yy = []
zz = []

for z_ in z:
    for x_ in x:
        for y_ in y:
            xx.append(x_)
            yy.append(y_)
            zz.append(z_)

mesh = np.array([xx, yy, zz])

e_field, v_hat, e_mag = experiment.EField_at_mesh(mesh)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')
#ax.scatter(mesh[0],mesh[1], mesh[2],s=0.4)
ax.quiver(mesh[0],mesh[1], mesh[2], e_field[0], e_field[1], e_field[2], length=0.5, normalize=True)
plt.show()
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %matplotlib widget
# %matplotlib notebook

fig, ax = plt.subplots()


def f(x, y):
    return np.sin(x) + np.cos(y)

x = np.linspace(0, 2 * np.pi, 120)
y = np.linspace(0, 2 * np.pi, 100).reshape(-1, 1)

# ims is a list of lists, each row is a list of artists to draw in the
# current frame; here we are just animating one artist, the image, in
# each frame
ims = []
for i in range(60):
    x += np.pi / 15.
    y += np.pi / 20.
    im = ax.imshow(f(x, y), animated=True)
    if i == 0:
        ax.imshow(f(x, y))  # show an initial one first
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims, interval=50, blit=True,
                                repeat_delay=1000)

# To save the animation, use e.g.
#
#ani.save("movie.mp4")
#
# or
#
# writer = animation.FFMpegWriter(
#     fps=15, metadata=dict(artist='Me'), bitrate=1800)
# ani.save("movie.mp4", writer=writer)

plt.show()
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axes3d as p3
import matplotlib.animation as animation

# Fixing random state for reproducibility
np.random.seed(19680801)


def Gen_RandLine(length, dims=2):
    """
    Create a line using a random walk algorithm

    length is the number of points for the line.
    dims is the number of dimensions the line has.
    """
    lineData = np.empty((dims, length))
    lineData[:, 0] = np.random.rand(dims)
    for index in range(1, length):
        # scaling the random numbers by 0.1 so
        # movement is small compared to position.
        # subtraction by 0.5 is to change the range to [-0.5, 0.5]
        # to allow a line to move backwards.
        step = ((np.random.rand(dims) - 0.5) * 0.1)
        lineData[:, index] = lineData[:, index - 1] + step

    return lineData


def update_lines(num, dataLines, lines):
    for line, data in zip(lines, dataLines):
        # NOTE: there is no .set_data() for 3 dim data...
        line.set_data(data[0:2, :num])
        line.set_3d_properties(data[2, :num])
    return lines

# Attaching 3D axis to the figure
fig = plt.figure()
ax = p3.Axes3D(fig)

# Fifty lines of random 3-D lines
data = [Gen_RandLine(25, 3) for index in range(50)]

# Creating fifty line objects.
# NOTE: Can't pass empty arrays into 3d version of plot()
lines = [ax.plot(dat[0, 0:1], dat[1, 0:1], dat[2, 0:1])[0] for dat in data]

# Setting the axes properties
ax.set_xlim3d([0.0, 1.0])
ax.set_xlabel('X')

ax.set_ylim3d([0.0, 1.0])
ax.set_ylabel('Y')

ax.set_zlim3d([0.0, 1.0])
ax.set_zlabel('Z')

ax.set_title('3D Test')

# Creating the Animation object
line_ani = animation.FuncAnimation(fig, update_lines, 25, fargs=(data, lines),
                                   interval=50, blit=False)

plt.show()

# %%
l=700e-9
c=299792458
f=c/l
h = 6.626e-34
E = h*f
j_to_ev = 1.602e-19
E_volt = E/j_to_ev
E_volt
# Out:
# 1.7713793710611736

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm


class WaveEquationFD:
    
    def __init__(self, N, D, Mx, My):
        self.N = N
        self.D = D
        self.Mx = Mx
        self.My = My
        self.tend = 6
        self.xmin = 0
        self.xmax = 2
        self.ymin = 0
        self.ymax = 2
        self.initialization()
        self.eqnApprox()
        
        
    def initialization(self):
        self.dx = (self.xmax - self.xmin)/self.Mx
        self.dy = (self.ymax - self.ymin)/self.My
        
        self.x = np.arange(self.xmin, self.xmax+self.dx, self.dx)
        self.y = np.arange(self.ymin, self.ymax+self.dy, self.dy)
        
        #----- Initial condition -----#
        self.u0 = lambda r, s: 0.1*np.sin(np.pi*r)*np.sin(np.pi*s/2)
        
        #----- Initial velocity -----#
        self.v0 = lambda a, b: 0
        
        #----- Boundary conditions -----#
        self.bxyt = lambda left, right, time: 0
        
        self.dt = (self.tend - 0)/self.N
        self.t = np.arange(0, self.tend+self.dt/2, self.dt)
        
        # Assertion for the condition of r < 1, for stability
        r = 4*self.D*self.dt**2/(self.dx**2+self.dy**2);
        assert r < 1, "r is bigger than 1!"

            
    def eqnApprox(self):
        #----- Approximation equation properties -----#
        self.rx = self.D*self.dt**2/self.dx**2
        self.ry = self.D*self.dt**2/self.dy**2
        self.rxy1 = 1 - self.rx - self.ry 
        self.rxy2 = self.rxy1*2

        #----- Initialization matrix u for solution -----#
        self.u = np.zeros((self.Mx+1, self.My+1))
        self.ut = np.zeros((self.Mx+1, self.My+1))
        self.u_1 = self.u.copy()
        
        #----- Fills initial condition and initial velocity -----#
        for j in range(1, self.Mx):
            for i in range(1, self.My):
                self.u[i,j] = self.u0(self.x[i], self.y[j])
                self.ut[i,j] = self.v0(self.x[i], self.y[j])
        
    
    def solve_and_animate(self):

        u_2 = np.zeros((self.Mx+1, self.My+1))
        
        xx, yy = np.meshgrid(self.x, self.y)
        
        fig = plt.figure()        
        ax = fig.add_subplot(111, projection='3d')
        
        wframe = None
        
        k = 0
        nsteps = self.N
        
        while k < nsteps:
            if wframe:
                ax.collections.remove(wframe)
                
            self.t = k*self.dt
            
            #----- Fills in boundary condition along y-axis (vertical, columns 0 and Mx) -----#
            for i in range(self.My+1):
                self.u[i, 0] = self.bxyt(self.x[0], self.y[i], self.t)
                self.u[i, self.Mx] = self.bxyt(self.x[self.Mx], self.y[i], self.t)
                
            for j in range(self.Mx+1):
                self.u[0, j] = self.bxyt(self.x[j], self.y[0], self.t)
                self.u[self.My, j] = self.bxyt(self.x[j], self.y[self.My], self.t)
                
            if k == 0:
                for j in range(1, self.My):
                    for i in range(1, self.Mx):
                        self.u[i,j] = 0.5*(self.rx*(self.u_1[i-1,j] + self.u_1[i+1,j])) \
                                + 0.5*(self.ry*(self.u_1[i,j-1] + self.u_1[i,j+1])) \
                                + self.rxy1*self.u[i,j] + self.dt*self.ut[i,j]
            else:
                for j in range(1, self.My):
                    for i in range(1, self.Mx):
                        self.u[i,j] = self.rx*(self.u_1[i-1,j] + self.u_1[i+1,j]) \
                            + self.ry*(self.u_1[i,j-1] + self.u_1[i,j+1]) \
                            + self.rxy2*self.u[i,j] - u_2[i,j]
                            
            u_2 = self.u_1.copy()
            self.u_1 = self.u.copy()
            
            wframe = ax.plot_surface(xx, yy, self.u, cmap=cm.coolwarm, linewidth=2, 
                    antialiased=False)
            
            ax.set_xlim3d(0, 2.0)
            ax.set_ylim3d(0, 2.0)
            ax.set_zlim3d(-1.5, 1.5)
            
            ax.set_xticks([0, 0.5, 1.0, 1.5, 2.0])
            ax.set_yticks([0, 0.5, 1.0, 1.5, 2.0])
            
            ax.set_xlabel("x")
            ax.set_ylabel("y")
            ax.set_zlabel("U")
            
            plt.pause(0.01)
            k += 0.5
    
    
def main():
    simulator = WaveEquationFD(200, 0.25, 50, 50)
    simulator.solve_and_animate()
    plt.show()
    
if __name__ == "__main__":
    main()
    

#N = 200 
#D = 0.25
#Mx = 50
#My = 50

# %%
"""
2D wave equation via FFT 

u_tt = u_xx + u_yy 

on [-1, 1]x[-1, 1], t > 0 and Dirichlet BC u=0
"""

import numpy as np
from scipy import interpolate
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm


class WaveEquation:
    
    def __init__(self, N):
        self.N = N
        self.x0 = -1.0
        self.xf = 1.0
        self.y0 = -1.0
        self.yf = 1.0
        self.initialization()
        self.initCond()
        
        
    def initialization(self):
        k = np.arange(self.N + 1)
        self.x = np.cos(k*np.pi/self.N)
        self.y = self.x.copy()
        self.xx, self.yy = np.meshgrid(self.x, self.y)
        
        self.dt = 6/self.N**2
        self.plotgap = round((1/3)/self.dt)
        self.dt = (1/3)/self.plotgap
        
        
    def initCond(self):
        self.vv = np.exp(-40*((self.xx-0.4)**2 + self.yy**2))
        self.vvold = self.vv.copy()
        
        
    def solve_and_animate(self):

        fig = plt.figure()
        
        ax = fig.add_subplot(111, projection='3d')
        
        tc = 0
        nstep = round(3*self.plotgap+1)
        wframe = None
        
        while tc < nstep:
            if wframe:
                ax.collections.remove(wframe)
                
            xxx = np.arange(self.x0, self.xf+1/16, 1/16)
            yyy = np.arange(self.y0, self.yf+1/16, 1/16)
            vvv = interpolate.interp2d(self.x, self.y, self.vv, kind='cubic')
            Z = vvv(xxx, yyy)
            
            xxf, yyf = np.meshgrid(np.arange(self.x0,self.xf+1/16,1/16), np.arange(self.y0,self.yf+1/16,1/16))
                
            wframe = ax.plot_surface(xxf, yyf, Z, cmap=cm.coolwarm, linewidth=0, 
                    antialiased=False)
            
            ax.set_xlim3d(self.x0, self.xf)
            ax.set_ylim3d(self.y0, self.yf)
            ax.set_zlim3d(-0.15, 1)
            
            ax.set_xlabel("x")
            ax.set_ylabel("y")
            ax.set_zlabel("U")
            
            ax.set_xticks([-1.0, -0.5, 0.0, 0.5, 1.0])
            ax.set_yticks([-1.0, -0.5, 0.0, 0.5, 1.0])
            
            fig.suptitle("Time = %1.3f" % (tc/(3*self.plotgap-1)-self.dt))
            #plt.tight_layout()
            ax.view_init(elev=30., azim=-110)
            plt.pause(0.01)
                
            uxx = np.zeros((self.N+1, self.N+1))
            uyy = np.zeros((self.N+1, self.N+1))
            ii = np.arange(1, self.N)
            
            for i in range(1, self.N):
                v = self.vv[i,:]
                V = np.hstack((v, np.flipud(v[ii])))
                U = np.fft.fft(V)
                U = U.real
                
                r1 = np.arange(self.N)
                r2 = 1j*np.hstack((r1, 0, -r1[:0:-1]))*U
                W1 = np.fft.ifft(r2)
                W1 = W1.real
                s1 = np.arange(self.N+1)
                s2 = np.hstack((s1, -s1[self.N-1:0:-1]))
                s3 = -s2**2*U
                W2 = np.fft.ifft(s3)
                W2 = W2.real
                
                uxx[i,ii] = W2[ii]/(1-self.x[ii]**2) - self.x[ii]*W1[ii]/(1-self.x[ii]**2)**(3/2)
                
            for j in range(1, self.N):
                v = self.vv[:,j]
                V = np.hstack((v, np.flipud(v[ii])))
                U = np.fft.fft(V)
                U = U.real
                
                r1 = np.arange(self.N)
                r2 = 1j*np.hstack((r1, 0, -r1[:0:-1]))*U
                W1 = np.fft.ifft(r2)
                W1 = W1.real
                s1 = np.arange(self.N+1)
                s2 = np.hstack((s1, -s1[self.N-1:0:-1]))
                s3 = -s2**2*U
                W2 = np.fft.ifft(s3)
                W2 = W2.real
                
                uyy[ii,j] = W2[ii]/(1-self.y[ii]**2) - self.y[ii]*W1[ii]/(1-self.y[ii]**2)**(3/2)
                
            vvnew = 2*self.vv - self.vvold + self.dt**2*(uxx+uyy)
            self.vvold = self.vv.copy()
            self.vv = vvnew.copy()
            tc += 1
        
    
def main():
    simulator = WaveEquation(30)
    simulator.solve_and_animate()
    plt.show()

    
if __name__ == "__main__":
    main()
