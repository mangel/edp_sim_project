# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

G = 6.674e-11
SUN_MASS = 1.989e30
EARTH_MASS = 5.972e24

# %%
sun={}
sun["mass"]=1
sun["pos"]=(0,0,0)

earth={}
earth["mass"]=1
earth["pos"]=(10,0,0)

# %%
pos = lambda a,b, t: [a*np.cos(t), b*np.sin(t)]

# %%
a=20
b=10
t=np.linspace(0,2*np.pi,100)
trajectory = pos(a,b,t)T
# Out:
#   File "<ipython-input-4-47256c820f78>", line 4
#     trajectory = pos(a,b,t)T
#                            ^
# SyntaxError: invalid syntax

# %%
plt.scatter([sun["pos"][0]], [sun["pos"][1]], )
plt.scatter(trajectory[0], trajectory[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-b869ee2e3d35> in <module>
#       1 plt.scatter([sun["pos"][0]], [sun["pos"][1]], )
# ----> 2 plt.scatter(trajectory[0], trajectory[1])
#
# NameError: name 'trajectory' is not defined

# %%
f_sun = lambda r: -G * SUN_MASS*EARTH_MASS / r**2

# %%
f_sun(152.1e9)
# Out:
# -3.4267494866737464e+22

# %%
import numpy as np
import emcee

def log_prob(x, ivar):
    return -0.5 * np.sum(ivar * x ** 2)

ndim, nwalkers = 5, 100
ivar = 1. / np.random.rand(ndim)
p0 = np.random.randn(nwalkers, ndim)

sampler = emcee.EnsembleSampler(nwalkers, ndim, log_prob, args=[ivar])
sampler.run_mcmc(p0, 10000)
# Out:
# State([[ 1.24923153e+00 -6.25539400e-01 -1.89022890e-01 -1.63386102e-01
#    2.15597262e-01]
#  [-1.45615977e-01  8.21267486e-01 -1.03555940e-01  1.17358948e-01
#    2.59626774e-01]
#  [ 7.69479285e-01 -6.39194257e-01  7.98092914e-01  2.08928181e-01
#    2.36213089e+00]
#  [ 5.22382517e-01  1.21133583e+00  7.74302122e-01  2.32304923e-01
#   -1.61733268e+00]
#  [ 2.76541206e-01 -6.58239315e-01  3.21479742e-01 -5.68943337e-01
#    4.27234262e-01]
#  [-9.46496089e-01  1.63514596e+00 -5.62668303e-01  3.62833151e-01
#    5.49624705e-01]
#  [ 3.15197425e-01  5.63941194e-01 -6.95327366e-01  8.21731194e-02
#    1.92004451e-01]
#  [-2.06838602e-02 -3.51466624e-01 -3.51573278e-01  3.22191247e-01
#    6.13397324e-01]
#  [ 1.43237960e+00 -1.46051756e-01  1.30813663e-01  2.11604508e-01
#   -1.50969155e+00]
#  [ 7.45573789e-01 -4.91868022e-02  1.13971376e-01 -1.75350292e-01
#    8.04366224e-01]
#  [ 6.10484548e-01  2.65242910e-01  6.93618621e-02 -1.20524621e-01
#    8.06259727e-01]
#  [ 6.94076620e-01 -2.80522295e-02 -6.51584525e-02 -2.64816800e-01
#   -6.61437545e-01]
#  [ 6.98208288e-01 -8.56509587e-01 -3.32998202e-01  1.89214971e-01
#    1.26324360e+00]
#  [ 1.21429977e+00 -1.12352720e+00 -7.39196228e-01  1.62675646e-01
#   -2.25393852e-02]
#  [ 3.87152556e-01  2.27716496e-01 -1.30802017e+00  2.74473877e-01
#    1.14890575e+00]
#  [ 7.95089513e-01 -3.91623410e-01 -4.64153135e-01  9.90305143e-02
#    1.80215858e-01]
#  [-2.15389646e-01  2.60818209e-01  2.93945272e-01 -5.63011742e-02
#   -5.54783932e-01]
#  [-7.52838198e-01  7.72765107e-01  2.49850861e-01  3.32220466e-01
#    5.99832334e-01]
#        1757142585, 3987546338, 1249981732, 1713584234,  885254371,
#        4262410869, 1982106592,  766355392,  175005017, 2074413050,
#         539466760,  501256030,  392002113, 1668715046, 2630843898,
#        2321763963, 2463285304,  479516116,  138496554,  779724305,
#         717326461, 3837448073, 2208961173, 2614083633,  585567756,
#        2246561827, 1463076670, 4267415231, 2456613407,  290670462,
#        2256873806, 3443256503, 2844102320,  105102412,  728881973,
#        1210462430, 3028382544,  227374902, 1092868937, 2213753755,
#        2215587021,  594245567, 2828345691, 1318801637, 3177141646,
#        3338705319, 2051255427, 3535526726,  957257523, 2344719076,
#        3897644019, 1576737096, 2658220755, 3266615208, 2653430171,
#        3446995896, 4100228001, 1265843652, 1039305361, 3753077369,
#        2935169909, 2682665657, 2523573422, 2173102657, 1493326535,
#         390934210, 2058689800,  665562079, 2082413365, 2045193383,
#        2194199952, 2236160721, 1215304705,  177294044, 1849621564,
#        3816626520, 3566150892,  253668469, 4110612552, 2784427942,
#        2964224323, 2852220337, 3551551806,  534097269, 3673572101,
#        2637179653, 2999580332,  845366649, 3488874960, 3583561847,
#        1658016605, 2955903836,  577750698, 1377515466, 1868510566,
#        1728450253, 1408251301, 1524312721, 1208457120, 1433629027,
#        3254350656,  182142630, 2400440683, 3715593926,  334782845,
#        1123907408, 3796836147, 1771255301,  522514458,  937794421,
#        3435066716, 3013907315, 3037185381,  463088290, 1620439446,
#        3017514940,  631194645, 2241609372,  726480394, 2218401913,
#        1779154887, 3891274265, 1462925788, 3482648441, 2540376517,
#         700705123,  760625811, 3917366946, 1268122346, 1204185962,
#        3902948271, 1891813315,  514619180, 1121166332, 4003263313,
#        3524462866, 4091200628, 2265062727,  594360854, 2215840398,
#          99426941,   17592224, 3851253603, 1549485668, 2664769858,
#        1430214198, 3631121253, 2547745948, 1619276618, 1987629996,
#        1822232832, 3129538623, 4108874997, 2960948045,  501250790,
#         937406061, 1042629091, 2446355852, 3242746164], dtype=uint32), 222, 0, 0.0))

# %%
# DRAW a vector field
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm

from mpl_toolkits.mplot3d import Axes3D

# %matplotlib inline

# rotate 3d graphs, and save
# %matplotlib widget
# %matplotlib notebook
# Out:
# Warning: Cannot change to a different GUI toolkit: notebook. Using widget instead.

# %%
x = np.linspace(-1,1,40)
y = x**2
plt.figure()
plt.plot(x,y)
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Text(0, 0.5, 'Y')

# %%
# Line in 3d
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

theta = np.linspace(-4*np.pi, 4*np.pi,100)
r = 2
x = r * np.sin(theta)
y = r * np.cos(theta)
z = 10*theta

ax.plot(x, y, z, label='helix')
ax.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Plot surface
N=50
x = np.linspace(-1,1,N)
y = np.linspace(-1,1,N)
z = np.linspace(-1,1,N)

fig = plt.figure(figsize=(5,3))
ax = fig.add_subplot(111, projection='3d')
splot = ax.plot_surface(x,y,z, cmap=cm.coolwarm)
fig.colorbar(splot)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-c70e3312f37f> in <module>
#       7 fig = plt.figure(figsize=(5,3))
#       8 ax = fig.add_subplot(111, projection='3d')
# ----> 9 splot = ax.plot_surface(x,y,z, cmap=cm.coolwarm)
#      10 fig.colorbar(splot)
#      11 ax.set_xlabel('X')
#
# /opt/anaconda/anaconda3/lib/python3.8/site-packages/mpl_toolkits/mplot3d/axes3d.py in plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1495
#    1496         if Z.ndim != 2:
# -> 1497             raise ValueError("Argument Z must be 2-dimensional.")
#    1498         if np.any(np.isnan(Z)):
#    1499             cbook._warn_external(
#
# ValueError: Argument Z must be 2-dimensional.

# %%
#countour plot
plt.figure()
plt.contour(x,y,z, levels=50, cmap=cm.coolwarm)
plt.colorbar()
plt.show()

# %%
#countour fill plot
plt.figure()
plt.contourf(x,y,z, levels=100, cmap=cm.coolwarm)
plt.colorbar()
plt.show()

# %%
# gradient
gx, gy = np.gradient(z, 2/N)

plt.figure()
plt.contourf(x,y,z, levels=100, cmap=cm.coolwarm)
plt.colorbar()
plt.quiver(x,y,gx,gy,scale=200) # make the vector plot
plt.show()

# %%
# Vector fields
x1 = np.linspace(-1,1,10)
y1 = np.linspace(-1,1,10)
x,y = np.meshgrid(x1,y1)
u = -y # the magnitude ofthe vectorfield in xhat direction
v = x # the magnitude ofthe vectorfield in yhat direction
plt.figure()
plt.quiver(x,y,u,v)
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
# Vector fields 3d
N=5
x1 = np.linspace(-1,1,N)
y1 = np.linspace(-1,1,N)
z1 = np.linspace(-1,1,N)
x,y,z = np.meshgrid(x1,y1,z1)

u = x
v = y
w = z

fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111, projection='3d')
ax.quiver(x,y,z,u,v,w)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()

# %%
# plot a single vector
x=0
y=0
z=0
u=0
v=2
w=5

fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111, projection='3d')
ax.quiver(x,y,z,u,v,w)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

ax.set_xlim(-10, 10)
ax.set_ylim(-10, 10)
ax.set_zlim(-10, 10)

plt.show()

# %%
#plot vectors at the same time

x = [0, 0, 0]
y = [0, 0, 0]
z = [0, 0, 0]

u = [0, 3, 3]
v = [2, 1, 1]
w = [3, -2, 1]

fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111, projection='3d')
ax.quiver(x,y,z,u,v,w)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

ax.set_xlim(-5, 5)
ax.set_ylim(-5, 5)
ax.set_zlim(-5, 5)

plt.show()

# %%
# Coordinate systems
# cartesian (x, y, z)
# cylindrical(r, theta, z)
# spherical(r, phi, theta)

# %%
# Plot surface
N=50
x = np.linspace(-1,1,N)
y = np.linspace(-1,1,N)
z = np.meshgrid(x1, y1)

z = np.cos(r*np.pi*2)

fig = plt.figure(figsize=(5,3))
ax = fig.add_subplot(111, projection='3d')
splot = ax.plot_surface(x,y,z, cmap=cm.coolwarm)
fig.colorbar(splot)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

fig, ax = plt.subplots()


def f(x, y):
    return np.sin(x) + np.cos(y)

x = np.linspace(0, 2 * np.pi, 120)
y = np.linspace(0, 2 * np.pi, 100).reshape(-1, 1)

# ims is a list of lists, each row is a list of artists to draw in the
# current frame; here we are just animating one artist, the image, in
# each frame
ims = []
for i in range(60):
    x += np.pi / 15.
    y += np.pi / 20.
    im = ax.imshow(f(x, y), animated=True)
    if i == 0:
        ax.imshow(f(x, y))  # show an initial one first
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims, interval=50, blit=True,
                                repeat_delay=1000)

# To save the animation, use e.g.
#
ani.save("movie.mp4")
#
# or
#
# writer = animation.FFMpegWriter(
#     fps=15, metadata=dict(artist='Me'), bitrate=1800)
# ani.save("movie.mp4", writer=writer)

plt.show()

# %%
from matplotlib import cbook
from matplotlib import cm
from matplotlib.colors import LightSource
import matplotlib.pyplot as plt
import numpy as np

dem = cbook.get_sample_data('jacksboro_fault_dem.npz', np_load=True)
z = dem['elevation']
nrows, ncols = z.shape
x = np.linspace(dem['xmin'], dem['xmax'], ncols)
y = np.linspace(dem['ymin'], dem['ymax'], nrows)
x, y = np.meshgrid(x, y)

region = np.s_[5:50, 5:50]
x, y, z = x[region], y[region], z[region]

fig, ax = plt.subplots(subplot_kw=dict(projection='3d'))

ls = LightSource(270, 45)
# To use a custom hillshading mode, override the built-in shading and pass
# in the rgb colors of the shaded surface calculated from "shade".
rgb = ls.shade(z, cmap=cm.gist_earth, vert_exag=0.1, blend_mode='soft')
surf = ax.plot_surface(x, y, z, rstride=1, cstride=1, facecolors=rgb,
                       linewidth=0, antialiased=False, shade=False)
ax.set_xticks([])
ax.set_yticks([])
ax.set_zticks([])
fig.savefig("surface3d_frontpage.png", dpi=25)  # results in 160x120 px image

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Grab some test data.
X, Y, Z = axes3d.get_test_data(0.05)

# Plot a basic wireframe.
ax.plot_wireframe(X, Y, Z, rstride=10, cstride=10)

plt.show()

# %%
X
# Out:
# array([[-30. , -29.5, -29. , ...,  28.5,  29. ,  29.5],
#        [-30. , -29.5, -29. , ...,  28.5,  29. ,  29.5],
#        [-30. , -29.5, -29. , ...,  28.5,  29. ,  29.5],
#        ...,
#        [-30. , -29.5, -29. , ...,  28.5,  29. ,  29.5],
#        [-30. , -29.5, -29. , ...,  28.5,  29. ,  29.5],
#        [-30. , -29.5, -29. , ...,  28.5,  29. ,  29.5]])

# %%
Y
# Out:
# array([[-30. , -30. , -30. , ..., -30. , -30. , -30. ],
#        [-29.5, -29.5, -29.5, ..., -29.5, -29.5, -29.5],
#        [-29. , -29. , -29. , ..., -29. , -29. , -29. ],
#        ...,
#        [ 28.5,  28.5,  28.5, ...,  28.5,  28.5,  28.5],
#        [ 29. ,  29. ,  29. , ...,  29. ,  29. ,  29. ],
#        [ 29.5,  29.5,  29.5, ...,  29.5,  29.5,  29.5]])

# %%
Z
# Out:
# array([[-0.00982064, -0.0113957 , -0.01319036, ..., -0.01522953,
#         -0.01319036, -0.0113957 ],
#        [-0.0113957 , -0.01322338, -0.01530587, ..., -0.01767209,
#         -0.01530587, -0.01322338],
#        [-0.01319036, -0.01530587, -0.01771632, ..., -0.02045518,
#         -0.01771632, -0.01530587],
#        ...,
#        [-0.01200234, -0.01414685, -0.01660867, ...,  0.02918791,
#          0.03019517,  0.03085725],
#        [-0.01097235, -0.01288301, -0.01507265, ...,  0.01583738,
#          0.01709512,  0.01804782],
#        [-0.00988645, -0.01157475, -0.01350698, ...,  0.00702321,
#          0.0083816 ,  0.00947216]])

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
from itertools import product, combinations


fig = plt.figure()
ax = fig.gca(projection='3d')
#ax.set_aspect("equal")

# draw cube
r = [-1, 1]
for s, e in combinations(np.array(list(product(r, r, r))), 2):
    if np.sum(np.abs(s-e)) == r[1]-r[0]:
        ax.plot3D(*zip(s, e), color="b")

# draw sphere
u, v = np.mgrid[0:2*np.pi:20j, 0:np.pi:10j]
x = np.cos(u)*np.sin(v)
y = np.sin(u)*np.sin(v)
z = np.cos(v)
ax.plot_wireframe(x, y, z, color="r")

# draw a point
ax.scatter([0], [0], [0], color="g", s=100)

# draw a vector
from matplotlib.patches import FancyArrowPatch
from mpl_toolkits.mplot3d import proj3d


class Arrow3D(FancyArrowPatch):

    def __init__(self, xs, ys, zs, *args, **kwargs):
        FancyArrowPatch.__init__(self, (0, 0), (0, 0), *args, **kwargs)
        self._verts3d = xs, ys, zs

    def draw(self, renderer):
        xs3d, ys3d, zs3d = self._verts3d
        xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
        self.set_positions((xs[0], ys[0]), (xs[1], ys[1]))
        FancyArrowPatch.draw(self, renderer)

a = Arrow3D([0, 1], [0, 1], [0, 1], mutation_scale=20,
            lw=1, arrowstyle="-|>", color="k")
ax.add_artist(a)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-2*np.pi, 2*np.pi, int(10e3))
y = np.sin(x)**2

plt.plot(x,y)
